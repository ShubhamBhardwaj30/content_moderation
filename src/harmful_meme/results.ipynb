# %% [markdown]
# # Pipeline Results Analysis
# This notebook loads the output from the feature generation pipeline (`historical_tags.csv`) to visualize VLM and Transformer outputs.

# %%
import pandas as pd
import sys
import os

# Ensure we can find the config file if running from this directory
sys.path.append(os.getcwd())

try:
    import config
    # Use the absolute path defined in config
    OUTPUT_FILE = config.OFFLINE_FILE
except ImportError:
    # Fallback if config import fails (e.g. environment issues)
    OUTPUT_FILE = "historical_tags.csv"

# Load Data
try:
    df = pd.read_csv(OUTPUT_FILE)
    print(f"Loaded {len(df)} rows from {OUTPUT_FILE}")
except FileNotFoundError:
    print(f"File not found at {OUTPUT_FILE}. Please run main.py first.")
# Out:
# Loaded 250 rows from /Users/shubhambhardwaj/Shubham/datascience/study/LLM/embeddings/research/harmful_meme/historical_tags.csv

# %% [markdown]
# ## 1. VLM & Text Transformer Outputs
# Here we view the raw outputs from the VLM (Visual Summary, OCR) and the Text Transformer (Keywords).

# %%
# Filter important columns for visibility
cols = ['post_id', 'post_text', 'visual_summary', 'ocr_text', 'keywords']

# Check if columns exist (in case CSV structure changed)
display_cols = [c for c in cols if c in df.columns]

if not df.empty:
    display(df[display_cols].head(100))
else:
    print("Dataframe is empty.")
# Out:
#     post_id                                          post_text  \
# 0     46971                              bravery at its finest
# 1      3745  your order comes to $37.50 and your white priv...
# 2     83745  it is time.. to send these parasites back to t...
# 3      5279  knowing white people , that's probably the bab...
# 4      1796       life hack #23 how to get stoned with no weed
# ..      ...                                                ...
# 95    84015                       my irony meter just exploded
# 96    87251            i love apes they are both ugly and cute
# 97    59738  what's the difference between a refugee and e....
# 98     3524     terrorist can come to this country way to easy
# 99    86170                         how to keep the thefts out
#
#                                        visual_summary  \
# 0   ['The image shows a man with a beard and glass...
# 1   ['A young woman with long blonde hair is stand...
# 2   ['A person in armor is holding a sword with a ...
# 3   ["A woman is standing next to a horse, both lo...
# 4   ['A woman in a hijab is giving a woman in a hi...
# ..                                                ...
# 95  ['A man in a blue shirt is being handcuffed by...
# 96  ["A child's face with a neutral expression is ...
# 97  ["A split-screen image of two older men, both ...
# 98  ['A crowd of people, some of whom are sitting ...
# 99  ["A black-and-white image of a group of people...
#
#                                              ocr_text  \
# 0                           ['bravery at its finest']
# 1   ['your order comes to $37.50\nand your white p...
# 2   ['it is time... to send these parasites back t...
# 3   ["knowing white people, that's probably the ba...
# 4        life hack #23 how to get stoned with no weed
# ..                                                ...
# 95                   ['my irony meter just exploded']
# 96        ['i love apes', 'they are both ugly and c']
# 97  ["what's the difference between a refugee and ...
# 98  ['terrorist can come to this country way, to e...
# 99                     ['how to keep the thefts out']
#
#                                              keywords
# 0   ['bravery', 'shows', 'shows:', "fingers.'].", ...
# 1   ['standing', 'text', 'total', 'image', 'discou...
# 2   ['back', 'text', 'desert.', 'image', 'time...'...
# 3   ['shirt', 'vest,', 'standing', 'green', 'trees...
# 4   ['giving', 'woman', 'hijab', 'weed', 'weed.', ...
# ..                                                ...
# 95  ['shirt', "exploded']", 'exploded.', 'police',...
# 96  ['love', 'text', 'both', "apes',", 'apes\'.",'...
# 97  ['bottom', 'one.', 'black', "'what's", 'text',...
# 98  ['else.', 'standing', 'facing', 'text', 'possi...
# 99  ["'how", 'superimposed', 'flags.', 'film', 'te...
#
# [100 rows x 5 columns]

# %% [markdown]
# ## 2. Generated Scores & Tags
# These are the policy scores and final binary decisions.

# %%
score_cols = [c for c in df.columns if 'Score' in c or 'Is_' in c]
if not df.empty:
    display(df[['post_id'] + score_cols].head(200))
# Out:
#      post_id  Is_Harmful_Content  Is_Political_Content  Is_Spam  \
# 0      46971                   0                     0        0
# 1       3745                   0                     0        0
# 2      83745                   0                     0        0
# 3       5279                   0                     1        0
# 4       1796                   0                     0        0
# ..       ...                 ...                   ...      ...
# 195    51306                   0                     1        0
# 196    50241                   0                     1        0
# 197    17045                   0                     0        0
# 198    89536                   0                     1        0
# 199    74906                   0                     0        0
#
#      Is_Copyright_Infringement
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ..                         ...
# 195                          0
# 196                          0
# 197                          0
# 198                          0
# 199                          0
#
# [200 rows x 5 columns]
